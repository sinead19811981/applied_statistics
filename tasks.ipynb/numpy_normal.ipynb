# %%
# Binomial distribution.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

import scipy.stats as stats

# %% [markdown]
# https://numpy.org/doc/2.0/reference/random/generated/numpy.random.normal.html#numpy-random-normal

# %%
# Generate a random normal sample.
data = np.random.normal(10.0, 3.0, 100000)

# Show.
data
# Out:
# array([13.32126277,  9.95782618,  4.3592086 , ...,  8.28061011,
#        11.19705344, 13.05000136])

# %%
mu, sigma = 10.0, 3.0 # mean and standard deviation
rng = np.random.default_rng()
s = rng.normal(mu, sigma, 100000)

# %%
abs(mu - np.mean(s))
0.0  # may vary
# Out:
# 0.0

# %%
abs(sigma - np.std(s, ddof=1))
0.0  # may vary
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
count, bins, _ = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
# Create a blank plot.
fig, ax = plt.subplots()

# Create a histogram.
ax.hist(data, edgecolor='black', density=True, bins=np.linspace(-4, 4, 31));

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Create a q-q plot.
stats.probplot(data, dist='norm', plot=ax);

# %% [markdown]
# # Shapiro-Wilk Test
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html#shapiro

# %%
# Create a blank plot.
fig, ax = plt.subplots()

# X values.
x = np.linspace(-4.0, 4.0, 1000)

# Plot the normal distribution.
plt.plot(x, stats.norm.pdf(x))

# Shade in some areas.
plt.fill_between(x, stats.norm.pdf(x), where=(x < -1.96) | (x > 1.96), color='red', alpha=0.7);
